# %%
! pip install pandas
! pip install matplotlib
! pip install numpy
! pip install scikit-learn
! pip install plotly
! pip install seaborn
# Out:
# ...
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 1.1 MB/s eta 0:00:09
#    --- ------------------------------------ 0.8/9.9 MB 1.3 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.3/9.9 MB 1.5 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/9.9 MB 1.6 MB/s eta 0:00:06
#    -------- ------------------------------- 2.1/9.9 MB 1.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.6/9.9 MB 1.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.9/9.9 MB 1.8 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/9.9 MB 1.9 MB/s eta 0:00:04
#    --------------- ------------------------ 3.9/9.9 MB 1.9 MB/s eta 0:00:04
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
! pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
uni = pd.read_excel(r'C:\Users\rajpu\Downloads\K-Means_Clustering_2025\K-Means_Clustering_2025\University.xlsx')

# %%
uni.head
# Out:
# <bound method NDFrame.head of     UnivID          Univ State     SAT  Top10  Accept  SFRatio  Expenses  \
# 0        1         Brown    RI  1310.0     89      22     13.0     22704
# 1        2       CalTech    CA  1415.0    100      25      6.0     63575
# 2        3           CMU    PA  1260.0     62      59      9.0     25026
# 3        4      Columbia    NY  1310.0     76      24     12.0     31510
# 4        5       Cornell    NY  1280.0     83      33     13.0     21864
# 5        6     Dartmouth    NH  1340.0     89      23     10.0     32162
# 6        7          Duke    NC  1315.0     90      30     12.0     31585
# 7        8    Georgetown    DC     NaN     74      24     12.0     20126
# 8        9       Harvard    MA  1400.0     91      14     11.0     39525
# 9       10  JohnsHopkins    MD  1305.0     75      44      7.0     58691
# 10      11           MIT    MA  1380.0     94      30     10.0     34870
# ...

# %%
df = uni
df.head(5)
# Out:
#    UnivID      Univ State     SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0       1     Brown    RI  1310.0     89      22     13.0     22704      94.0
# 1       2   CalTech    CA  1415.0    100      25      6.0     63575      81.0
# 2       3       CMU    PA  1260.0     62      59      9.0     25026      72.0
# 3       4  Columbia    NY  1310.0     76      24     12.0     31510       NaN
# 4       5   Cornell    NY  1280.0     83      33     13.0     21864      90.0

# %%
df.describe()
# Out:
#           UnivID          SAT       Top10     Accept    SFRatio      Expenses  \
# count  25.000000    24.000000   25.000000  25.000000  24.000000     25.000000
# mean   13.000000  1266.916667   76.480000  39.200000  12.708333  27388.000000
# std     7.359801   110.663578   19.433905  19.727308   4.154402  14424.883165
# min     1.000000  1005.000000   28.000000  14.000000   6.000000   8704.000000
# 25%     7.000000  1236.250000   74.000000  24.000000  10.750000  15140.000000
# 50%    13.000000  1287.500000   81.000000  36.000000  12.000000  27553.000000
# 75%    19.000000  1345.000000   90.000000  50.000000  14.250000  34870.000000
# max    25.000000  1415.000000  100.000000  90.000000  25.000000  63575.000000
#
#         GradRate
# count  24.000000
# mean   86.666667
# std     9.248580
# min    67.000000
# 25%    80.750000
# 50%    90.000000
# 75%    94.000000
# max    97.000000

# %%
df_1 = df.dropna()
df_1
# Out:
#     UnivID          Univ State     SAT  Top10  Accept  SFRatio  Expenses  \
# 0        1         Brown    RI  1310.0     89      22     13.0     22704
# 1        2       CalTech    CA  1415.0    100      25      6.0     63575
# 2        3           CMU    PA  1260.0     62      59      9.0     25026
# 4        5       Cornell    NY  1280.0     83      33     13.0     21864
# 5        6     Dartmouth    NH  1340.0     89      23     10.0     32162
# 6        7          Duke    NC  1315.0     90      30     12.0     31585
# 8        9       Harvard    MA  1400.0     91      14     11.0     39525
# 9       10  JohnsHopkins    MD  1305.0     75      44      7.0     58691
# 10      11           MIT    MA  1380.0     94      30     10.0     34870
# 11      12  Northwestern    IL  1260.0     85      39     11.0     28052
# 12      13     NotreDame    IN  1255.0     81      42     13.0     15122
# 13      14     PennState    PA  1081.0     38      54     18.0     10185
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 22 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   UnivID    22 non-null     int64
#  1   Univ      22 non-null     str
#  2   State     22 non-null     str
#  3   SAT       22 non-null     float64
#  4   Top10     22 non-null     int64
#  5   Accept    22 non-null     int64
#  6   SFRatio   22 non-null     float64
#  7   Expenses  22 non-null     int64
#  8   GradRate  22 non-null     float64
# dtypes: float64(3), int64(4), str(2)
# memory usage: 1.7 KB

# %%
! pip install --upgrade pip
! pip install scikit-learn --no-cache-dir
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 1.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.6 MB/s  0:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 26.0.1
#     Uninstalling pip-26.0.1:
#       Successfully uninstalled pip-26.0.1
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 2.2 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/8.1 MB 1.7 MB/s eta 0:00:05
# ...

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
X = df_1.select_dtypes(include=['number'])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# apply KMeans
model = KMeans(n_clusters=3, random_state=42)
model.fit(X_scaled)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
# results
df_1['Cluster'] = model.labels_

# %%
print(df_1.head())
print("Centroids:\n", model.cluster_centers_)
# Out:
#    UnivID       Univ State     SAT  Top10  Accept  SFRatio  Expenses  \
# 0       1      Brown    RI  1310.0     89      22     13.0     22704
# 1       2    CalTech    CA  1415.0    100      25      6.0     63575
# 2       3        CMU    PA  1260.0     62      59      9.0     25026
# 4       5    Cornell    NY  1280.0     83      33     13.0     21864
# 5       6  Dartmouth    NH  1340.0     89      23     10.0     32162
#
#    GradRate  Cluster
# 0      94.0        0
# 1      81.0        0
# 2      72.0        2
# 4      90.0        0
# 5      95.0        0
# Centroids:
#  [[-0.13953784  0.49801177  0.54864867 -0.52183891 -0.373706    0.34643219
#    0.49588629]
#  [ 0.7328496  -1.58669616 -1.6109378   1.48018709  1.3737379  -1.08143536
#   -1.27973779]
#  [-1.4316425  -0.03470747 -0.72368972  0.94848711 -0.88939349 -0.13573823
#   -1.5354916 ]]

# %%
print(df_1['Cluster'].value_counts())
# Out:
# Cluster
# 0    16
# 1     5
# 2     1
# Name: count, dtype: int64

# %%
centroids = pd.DataFrame(model.cluster_centers_, columns=X.columns)
print(centroids)
# Out:
#      UnivID       SAT     Top10    Accept   SFRatio  Expenses  GradRate
# 0 -0.139538  0.498012  0.548649 -0.521839 -0.373706  0.346432  0.495886
# 1  0.732850 -1.586696 -1.610938  1.480187  1.373738 -1.081435 -1.279738
# 2 -1.431643 -0.034707 -0.723690  0.948487 -0.889393 -0.135738 -1.535492

# %%
wcss = []

for i in range(1, 10):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,10), wcss)
plt.xlabel('K')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()
